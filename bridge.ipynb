# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D
from keras.callbacks import ModelCheckpoint, EarlyStopping
import matplotlib.pyplot as plt
import numpy as np
import cv2
from sklearn.model_selection import train_test_split

# %% [markdown]
# # 데이터셋 생성

# %%
import os

X = np.empty((2000, 64, 64, 3))
Y = np.empty((2000,))

target = 'Bridge'

folders = os.listdir('./images')
folders.remove(target)
folders.remove('Other')

files = os.listdir(f'./images/{target}')
for i in range(1000):
    x = cv2.imread(f"./images/{target}/{files[i]}")
    X[i] = cv2.resize(x, (64, 64))
    Y[i] = 1

files = os.listdir('./images/Other')
for i in range(300):
    x = cv2.imread(f"./images/Other/{files[i]}")
    X[i+1000] = cv2.resize(x, (64, 64))
    Y[i+1000] = 0

for f in range(7):
    files = os.listdir(f'./images/{folders[f]}')
    for i in range(100):
        x = cv2.imread(f"./images/{folders[f]}/{files[i]}")
        X[1300+f*100+i] = cv2.resize(x, (64, 64))
        Y[1300+f*100+i] = 0

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, random_state=0)

# %%
print(X_train.shape)
print(X_test.shape)
print( y_train.shape)
print(y_test.shape)
# Out:
# (1500, 64, 64, 3)
# (500, 64, 64, 3)
# (1500,)
# (500,)

# %% [markdown]
# # 모델 생성

# %%
model = Sequential()
model.add(Conv2D(16, (3,3), activation='relu', input_shape=(64, 64, 3)))
model.add(MaxPooling2D())
model.add(Conv2D(64, (3,3), activation='relu'))
model.add(MaxPooling2D())
model.add(Conv2D(256, (3,3), activation='relu'))
model.add(MaxPooling2D())
model.add(Conv2D(1024, (3,3), activation='relu'))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(
    optimizer='adam', 
    loss='binary_crossentropy', 
    metrics=[
        'accuracy',
    ],
)

# %%
modelpath=f"./history/{target.lower()}.hdf5"
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', verbose=1, save_best_only=True)
early_stopping_callback = EarlyStopping(monitor='val_loss', patience=5)

# %%
history = model.fit(X_train, y_train, validation_split=0.25, epochs=30, batch_size=100, verbose='auto', callbacks=[early_stopping_callback,checkpointer])
# Out:
# Epoch 1/30
# 12/12 [==============================] - ETA: 0s - loss: 4.1199 - accuracy: 0.5067
# Epoch 1: val_loss improved from inf to 0.69295, saving model to ./history\bridge.hdf5
# 12/12 [==============================] - 15s 905ms/step - loss: 4.1199 - accuracy: 0.5067 - val_loss: 0.6930 - val_accuracy: 0.5253
# Epoch 2/30
# 12/12 [==============================] - ETA: 0s - loss: 0.6980 - accuracy: 0.4907
# Epoch 2: val_loss improved from 0.69295 to 0.69282, saving model to ./history\bridge.hdf5
# 12/12 [==============================] - 10s 868ms/step - loss: 0.6980 - accuracy: 0.4907 - val_loss: 0.6928 - val_accuracy: 0.4800
# Epoch 3/30
# 12/12 [==============================] - ETA: 0s - loss: 0.6924 - accuracy: 0.5280
# Epoch 3: val_loss improved from 0.69282 to 0.67893, saving model to ./history\bridge.hdf5
# 12/12 [==============================] - 11s 885ms/step - loss: 0.6924 - accuracy: 0.5280 - val_loss: 0.6789 - val_accuracy: 0.6080
# Epoch 4/30
# 12/12 [==============================] - ETA: 0s - loss: 0.6689 - accuracy: 0.5778
# Epoch 4: val_loss improved from 0.67893 to 0.65802, saving model to ./history\bridge.hdf5
# 12/12 [==============================] - 10s 870ms/step - loss: 0.6689 - accuracy: 0.5778 - val_loss: 0.6580 - val_accuracy: 0.5867
# Epoch 5/30
# 12/12 [==============================] - ETA: 0s - loss: 0.6200 - accuracy: 0.6649
# Epoch 5: val_loss improved from 0.65802 to 0.55334, saving model to ./history\bridge.hdf5
# 12/12 [==============================] - 11s 887ms/step - loss: 0.6200 - accuracy: 0.6649 - val_loss: 0.5533 - val_accuracy: 0.7253
# Epoch 6/30
# 12/12 [==============================] - ETA: 0s - loss: 0.5550 - accuracy: 0.7182
# Epoch 6: val_loss improved from 0.55334 to 0.53629, saving model to ./history\bridge.hdf5
# 12/12 [==============================] - 10s 869ms/step - loss: 0.5550 - accuracy: 0.7182 - val_loss: 0.5363 - val_accuracy: 0.7520
# Epoch 7/30
# 12/12 [==============================] - ETA: 0s - loss: 0.5492 - accuracy: 0.7440
# Epoch 7: val_loss did not improve from 0.53629
# 12/12 [==============================] - 10s 867ms/step - loss: 0.5492 - accuracy: 0.7440 - val_loss: 0.5821 - val_accuracy: 0.6853
# Epoch 8/30
# 12/12 [==============================] - ETA: 0s - loss: 0.5137 - accuracy: 0.7636
# Epoch 8: val_loss did not improve from 0.53629
# 12/12 [==============================] - 10s 824ms/step - loss: 0.5137 - accuracy: 0.7636 - val_loss: 0.5786 - val_accuracy: 0.7227
# Epoch 9/30
# 12/12 [==============================] - ETA: 0s - loss: 0.4870 - accuracy: 0.7822
# Epoch 9: val_loss improved from 0.53629 to 0.46258, saving model to ./history\bridge.hdf5
# 12/12 [==============================] - 10s 836ms/step - loss: 0.4870 - accuracy: 0.7822 - val_loss: 0.4626 - val_accuracy: 0.7653
# Epoch 10/30
# 12/12 [==============================] - ETA: 0s - loss: 0.4099 - accuracy: 0.8222
# Epoch 10: val_loss did not improve from 0.46258
# 12/12 [==============================] - 11s 882ms/step - loss: 0.4099 - accuracy: 0.8222 - val_loss: 0.4855 - val_accuracy: 0.7627
# Epoch 11/30
# 12/12 [==============================] - ETA: 0s - loss: 0.3761 - accuracy: 0.8356
# Epoch 11: val_loss improved from 0.46258 to 0.45011, saving model to ./history\bridge.hdf5
# 12/12 [==============================] - 10s 846ms/step - loss: 0.3761 - accuracy: 0.8356 - val_loss: 0.4501 - val_accuracy: 0.7680
# Epoch 12/30
# 12/12 [==============================] - ETA: 0s - loss: 0.3237 - accuracy: 0.8613
# Epoch 12: val_loss did not improve from 0.45011
# 12/12 [==============================] - 10s 847ms/step - loss: 0.3237 - accuracy: 0.8613 - val_loss: 0.5249 - val_accuracy: 0.7547
# Epoch 13/30
# 12/12 [==============================] - ETA: 0s - loss: 0.2960 - accuracy: 0.8791
# Epoch 13: val_loss improved from 0.45011 to 0.42333, saving model to ./history\bridge.hdf5
# 12/12 [==============================] - 10s 836ms/step - loss: 0.2960 - accuracy: 0.8791 - val_loss: 0.4233 - val_accuracy: 0.8080
# Epoch 14/30
# 12/12 [==============================] - ETA: 0s - loss: 0.2763 - accuracy: 0.8853
# Epoch 14: val_loss did not improve from 0.42333
# 12/12 [==============================] - 10s 873ms/step - loss: 0.2763 - accuracy: 0.8853 - val_loss: 0.4464 - val_accuracy: 0.8213
# Epoch 15/30
# 12/12 [==============================] - ETA: 0s - loss: 0.2999 - accuracy: 0.8596
# Epoch 15: val_loss improved from 0.42333 to 0.40485, saving model to ./history\bridge.hdf5
# 12/12 [==============================] - 10s 843ms/step - loss: 0.2999 - accuracy: 0.8596 - val_loss: 0.4049 - val_accuracy: 0.8160
# Epoch 16/30
# 12/12 [==============================] - ETA: 0s - loss: 0.2181 - accuracy: 0.8969
# Epoch 16: val_loss did not improve from 0.40485
# 12/12 [==============================] - 10s 856ms/step - loss: 0.2181 - accuracy: 0.8969 - val_loss: 0.7269 - val_accuracy: 0.7627
# Epoch 17/30
# 12/12 [==============================] - ETA: 0s - loss: 0.1909 - accuracy: 0.9280
# Epoch 17: val_loss did not improve from 0.40485
# 12/12 [==============================] - 10s 826ms/step - loss: 0.1909 - accuracy: 0.9280 - val_loss: 0.4530 - val_accuracy: 0.8320
# Epoch 18/30
# 12/12 [==============================] - ETA: 0s - loss: 0.1819 - accuracy: 0.9253
# Epoch 18: val_loss did not improve from 0.40485
# 12/12 [==============================] - 10s 839ms/step - loss: 0.1819 - accuracy: 0.9253 - val_loss: 0.6021 - val_accuracy: 0.8133
# Epoch 19/30
# 12/12 [==============================] - ETA: 0s - loss: 0.1703 - accuracy: 0.9369
# Epoch 19: val_loss did not improve from 0.40485
# 12/12 [==============================] - 10s 841ms/step - loss: 0.1703 - accuracy: 0.9369 - val_loss: 0.5480 - val_accuracy: 0.8107
# Epoch 20/30
# 12/12 [==============================] - ETA: 0s - loss: 0.1479 - accuracy: 0.9476
# Epoch 20: val_loss did not improve from 0.40485
# 12/12 [==============================] - 10s 837ms/step - loss: 0.1479 - accuracy: 0.9476 - val_loss: 0.6991 - val_accuracy: 0.8107

# %%
model.evaluate(X_train, y_train)
model.evaluate(X_test, y_test)
# Out:
# 47/47 [==============================] - 3s 54ms/step - loss: 0.2629 - accuracy: 0.9167
# 16/16 [==============================] - 1s 57ms/step - loss: 0.6166 - accuracy: 0.8460
# [0.6165647506713867, 0.8460000157356262]

# %%
val_loss = history.history['val_loss']
loss = history.history['loss']

x_len = np.arange(len(loss))
plt.plot(x_len, val_loss, marker='.', c="red", label='val_loss')
plt.plot(x_len, loss, marker='.', c="blue", label='loss')

plt.legend(loc='upper right')
plt.grid()
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()

# %%
val_accuracy = history.history['val_accuracy']
accuracy = history.history['accuracy']

x_len = np.arange(len(accuracy))
plt.plot(x_len, val_accuracy, marker='.', c="red", label='val_accuracy')
plt.plot(x_len, accuracy, marker='.', c="blue", label='accuracy')

plt.legend(loc='upper right')
plt.grid()
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.show()

# %%
model.save(f"./models/{target.lower()}.hdf5")

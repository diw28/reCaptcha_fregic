# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D
from keras.callbacks import ModelCheckpoint, EarlyStopping
import matplotlib.pyplot as plt
import numpy as np
import cv2
from sklearn.model_selection import train_test_split

# %% [markdown]
# # 데이터셋 생성

# %%
import os

X = np.empty((2000, 64, 64, 3))
Y = np.empty((2000,))

target = 'Bridge'

folders = os.listdir('./images')
folders.remove(target)
folders.remove('Other')

files = os.listdir(f'./images/{target}')
for i in range(1000):
    x = cv2.imread(f"./images/{target}/{files[i]}")
    X[i] = cv2.resize(x, (64, 64))
    Y[i] = 1

files = os.listdir('./images/Other')
for i in range(300):
    x = cv2.imread(f"./images/Other/{files[i]}")
    X[i+1000] = cv2.resize(x, (64, 64))
    Y[i+1000] = 0

for f in range(7):
    files = os.listdir(f'./images/{folders[f]}')
    for i in range(100):
        x = cv2.imread(f"./images/{folders[f]}/{files[i]}")
        X[1300+f*100+i] = cv2.resize(x, (64, 64))
        Y[1300+f*100+i] = 0

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, random_state=0)

# %%
print(X_train.shape)
print(X_test.shape)
print( y_train.shape)
print(y_test.shape)
# Out:
# (1500, 64, 64, 3)
# (500, 64, 64, 3)
# (1500,)
# (500,)

# %% [markdown]
# # 모델 생성

# %%
model = Sequential()
model.add(Conv2D(16, (3,3), activation='relu', input_shape=(64, 64, 3)))
model.add(MaxPooling2D())
model.add(Conv2D(64, (3,3), activation='relu'))
model.add(MaxPooling2D())
model.add(Conv2D(256, (3,3), activation='relu'))
model.add(MaxPooling2D())
model.add(Conv2D(1024, (3,3), activation='relu'))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(
    optimizer='adam', 
    loss='binary_crossentropy', 
    metrics=[
        'accuracy',
    ],
)

# %%
modelpath=f"./history/{target.lower()}.hdf5"
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', verbose=1, save_best_only=True)
early_stopping_callback = EarlyStopping(monitor='val_loss', patience=5)

# %%
history = model.fit(X_train, y_train, validation_split=0.25, epochs=30, batch_size=100, verbose='auto', callbacks=[early_stopping_callback,checkpointer])
# Out:
# Epoch 1/30
# 12/12 [==============================] - ETA: 0s - loss: 4.8409 - accuracy: 0.4978
# Epoch 1: val_loss improved from inf to 0.68934, saving model to ./history\bridge.hdf5
# 12/12 [==============================] - 14s 903ms/step - loss: 4.8409 - accuracy: 0.4978 - val_loss: 0.6893 - val_accuracy: 0.5547
# Epoch 2/30
# c:\Users\Noah\anaconda3\Lib\site-packages\keras\src\engine\training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 12/12 [==============================] - ETA: 0s - loss: 0.7152 - accuracy: 0.4844
# Epoch 2: val_loss did not improve from 0.68934
# 12/12 [==============================] - 10s 829ms/step - loss: 0.7152 - accuracy: 0.4844 - val_loss: 0.6930 - val_accuracy: 0.5253
# Epoch 3/30
# 12/12 [==============================] - ETA: 0s - loss: 0.6996 - accuracy: 0.4836
# Epoch 3: val_loss improved from 0.68934 to 0.68823, saving model to ./history\bridge.hdf5
# 12/12 [==============================] - 11s 896ms/step - loss: 0.6996 - accuracy: 0.4836 - val_loss: 0.6882 - val_accuracy: 0.5253
# Epoch 4/30
# 12/12 [==============================] - ETA: 0s - loss: 0.6819 - accuracy: 0.5431
# Epoch 4: val_loss did not improve from 0.68823
# 12/12 [==============================] - 10s 844ms/step - loss: 0.6819 - accuracy: 0.5431 - val_loss: 0.7187 - val_accuracy: 0.5253
# Epoch 5/30
# 12/12 [==============================] - ETA: 0s - loss: 0.6493 - accuracy: 0.6258
# Epoch 5: val_loss improved from 0.68823 to 0.63502, saving model to ./history\bridge.hdf5
# 12/12 [==============================] - 11s 897ms/step - loss: 0.6493 - accuracy: 0.6258 - val_loss: 0.6350 - val_accuracy: 0.6107
# Epoch 6/30
# 12/12 [==============================] - ETA: 0s - loss: 0.6358 - accuracy: 0.6382
# Epoch 6: val_loss improved from 0.63502 to 0.60490, saving model to ./history\bridge.hdf5
# 12/12 [==============================] - 10s 850ms/step - loss: 0.6358 - accuracy: 0.6382 - val_loss: 0.6049 - val_accuracy: 0.6560
# Epoch 7/30
# 12/12 [==============================] - ETA: 0s - loss: 0.5796 - accuracy: 0.7253
# Epoch 7: val_loss improved from 0.60490 to 0.55000, saving model to ./history\bridge.hdf5
# 12/12 [==============================] - 10s 847ms/step - loss: 0.5796 - accuracy: 0.7253 - val_loss: 0.5500 - val_accuracy: 0.7333
# Epoch 8/30
# 12/12 [==============================] - ETA: 0s - loss: 0.5599 - accuracy: 0.7360
# Epoch 8: val_loss improved from 0.55000 to 0.53582, saving model to ./history\bridge.hdf5
# 12/12 [==============================] - 11s 881ms/step - loss: 0.5599 - accuracy: 0.7360 - val_loss: 0.5358 - val_accuracy: 0.7253
# Epoch 9/30
# 12/12 [==============================] - ETA: 0s - loss: 0.5385 - accuracy: 0.7493
# Epoch 9: val_loss improved from 0.53582 to 0.52805, saving model to ./history\bridge.hdf5
# 12/12 [==============================] - 10s 848ms/step - loss: 0.5385 - accuracy: 0.7493 - val_loss: 0.5281 - val_accuracy: 0.7573
# Epoch 10/30
# 12/12 [==============================] - ETA: 0s - loss: 0.5047 - accuracy: 0.7742
# Epoch 10: val_loss improved from 0.52805 to 0.47269, saving model to ./history\bridge.hdf5
# 12/12 [==============================] - 10s 871ms/step - loss: 0.5047 - accuracy: 0.7742 - val_loss: 0.4727 - val_accuracy: 0.7440
# Epoch 11/30
# 12/12 [==============================] - ETA: 0s - loss: 0.4844 - accuracy: 0.7573
# Epoch 11: val_loss did not improve from 0.47269
# 12/12 [==============================] - 11s 888ms/step - loss: 0.4844 - accuracy: 0.7573 - val_loss: 0.4812 - val_accuracy: 0.7813
# Epoch 12/30
# 12/12 [==============================] - ETA: 0s - loss: 0.4084 - accuracy: 0.8080
# Epoch 12: val_loss improved from 0.47269 to 0.44130, saving model to ./history\bridge.hdf5
# 12/12 [==============================] - 11s 892ms/step - loss: 0.4084 - accuracy: 0.8080 - val_loss: 0.4413 - val_accuracy: 0.7973
# Epoch 13/30
# 12/12 [==============================] - ETA: 0s - loss: 0.3751 - accuracy: 0.8382
# Epoch 13: val_loss improved from 0.44130 to 0.42490, saving model to ./history\bridge.hdf5
# 12/12 [==============================] - 10s 844ms/step - loss: 0.3751 - accuracy: 0.8382 - val_loss: 0.4249 - val_accuracy: 0.8053
# Epoch 14/30
# 12/12 [==============================] - ETA: 0s - loss: 0.3433 - accuracy: 0.8578
# Epoch 14: val_loss did not improve from 0.42490
# 12/12 [==============================] - 10s 847ms/step - loss: 0.3433 - accuracy: 0.8578 - val_loss: 0.4291 - val_accuracy: 0.8053
# Epoch 15/30
# 12/12 [==============================] - ETA: 0s - loss: 0.2885 - accuracy: 0.8720
# Epoch 15: val_loss improved from 0.42490 to 0.41519, saving model to ./history\bridge.hdf5
# 12/12 [==============================] - 10s 852ms/step - loss: 0.2885 - accuracy: 0.8720 - val_loss: 0.4152 - val_accuracy: 0.8293
# Epoch 16/30
# 12/12 [==============================] - ETA: 0s - loss: 0.2423 - accuracy: 0.8889
# Epoch 16: val_loss did not improve from 0.41519
# 12/12 [==============================] - 10s 850ms/step - loss: 0.2423 - accuracy: 0.8889 - val_loss: 0.4480 - val_accuracy: 0.8187
# Epoch 17/30
# 12/12 [==============================] - ETA: 0s - loss: 0.2955 - accuracy: 0.8791
# Epoch 17: val_loss did not improve from 0.41519
# 12/12 [==============================] - 10s 840ms/step - loss: 0.2955 - accuracy: 0.8791 - val_loss: 0.5373 - val_accuracy: 0.8107
# Epoch 18/30
# 12/12 [==============================] - ETA: 0s - loss: 0.2190 - accuracy: 0.9076
# Epoch 18: val_loss did not improve from 0.41519
# 12/12 [==============================] - 10s 841ms/step - loss: 0.2190 - accuracy: 0.9076 - val_loss: 0.4887 - val_accuracy: 0.8400
# Epoch 19/30
# 12/12 [==============================] - ETA: 0s - loss: 0.1596 - accuracy: 0.9271
# Epoch 19: val_loss did not improve from 0.41519
# 12/12 [==============================] - 10s 846ms/step - loss: 0.1596 - accuracy: 0.9271 - val_loss: 0.5112 - val_accuracy: 0.8453
# Epoch 20/30
# 12/12 [==============================] - ETA: 0s - loss: 0.1283 - accuracy: 0.9484
# Epoch 20: val_loss did not improve from 0.41519
# 12/12 [==============================] - 10s 859ms/step - loss: 0.1283 - accuracy: 0.9484 - val_loss: 0.5607 - val_accuracy: 0.8507

# %%
model.evaluate(X_train, y_train)
model.evaluate(X_test, y_test)
# Out:
# 47/47 [==============================] - 3s 54ms/step - loss: 0.2629 - accuracy: 0.9167
# 16/16 [==============================] - 1s 57ms/step - loss: 0.6166 - accuracy: 0.8460
# [0.6165647506713867, 0.8460000157356262]

# %%
val_loss = history.history['val_loss']
loss = history.history['loss']

x_len = np.arange(len(loss))
plt.plot(x_len, val_loss, marker='.', c="red", label='val_loss')
plt.plot(x_len, loss, marker='.', c="blue", label='loss')

plt.legend(loc='upper right')
plt.grid()
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()

# %%
val_accuracy = history.history['val_accuracy']
accuracy = history.history['accuracy']

x_len = np.arange(len(accuracy))
plt.plot(x_len, val_accuracy, marker='.', c="red", label='val_accuracy')
plt.plot(x_len, accuracy, marker='.', c="blue", label='accuracy')

plt.legend(loc='upper right')
plt.grid()
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.show()

# %%
model.save(f"./models/{target.lower()}.hdf5")

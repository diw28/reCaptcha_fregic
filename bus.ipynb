# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D
from keras.callbacks import ModelCheckpoint, EarlyStopping
import matplotlib.pyplot as plt
import numpy as np
import cv2
from sklearn.model_selection import train_test_split

# %% [markdown]
# # 데이터셋 생성

# %%
import os

X = np.empty((2000, 64, 64, 3))
Y = np.empty((2000,))

target = 'Bus'

folders = os.listdir('./images')
folders.remove(target)
folders.remove('Other')

files = os.listdir(f'./images/{target}')
for i in range(1000):
    x = cv2.imread(f"./images/{target}/{files[i]}")
    X[i] = cv2.resize(x, (64, 64))
    Y[i] = 1

files = os.listdir('./images/Other')
for i in range(300):
    x = cv2.imread(f"./images/Other/{files[i]}")
    X[i+1000] = cv2.resize(x, (64, 64))
    Y[i+1000] = 0

for f in range(7):
    files = os.listdir(f'./images/{folders[f]}')
    for i in range(100):
        x = cv2.imread(f"./images/{folders[f]}/{files[i]}")
        X[1300+f*100+i] = cv2.resize(x, (64, 64))
        Y[1300+f*100+i] = 0

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, random_state=0)

# %%
print(X_train.shape)
print(X_test.shape)
print( y_train.shape)
print(y_test.shape)
# Out:
# (1500, 64, 64, 3)
# (500, 64, 64, 3)
# (1500,)
# (500,)

# %% [markdown]
# # 모델 생성

# %%
model = Sequential()
model.add(Conv2D(16, (3,3), activation='relu', input_shape=(64, 64, 3)))
model.add(MaxPooling2D())
model.add(Conv2D(64, (3,3), activation='relu'))
model.add(MaxPooling2D())
model.add(Conv2D(256, (3,3), activation='relu'))
model.add(MaxPooling2D())
model.add(Conv2D(1024, (3,3), activation='relu'))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(
    optimizer='adam', 
    loss='binary_crossentropy', 
    metrics=[
        'accuracy',
    ],
)

# %%
modelpath=f"./history/{target.lower()}.hdf5"
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', verbose=1, save_best_only=True)
early_stopping_callback = EarlyStopping(monitor='val_loss', patience=5)

# %%
history = model.fit(X_train, y_train, validation_split=0.25, epochs=30, batch_size=100, verbose='auto', callbacks=[early_stopping_callback,checkpointer])
# Out:
# Epoch 1/30
# 12/12 [==============================] - ETA: 0s - loss: 2.9059 - accuracy: 0.5236
# Epoch 1: val_loss improved from inf to 0.73244, saving model to ./history\bus.hdf5
# 12/12 [==============================] - 15s 910ms/step - loss: 2.9059 - accuracy: 0.5236 - val_loss: 0.7324 - val_accuracy: 0.4747
# Epoch 2/30
# 12/12 [==============================] - ETA: 0s - loss: 0.6938 - accuracy: 0.5431
# Epoch 2: val_loss improved from 0.73244 to 0.67088, saving model to ./history\bus.hdf5
# 12/12 [==============================] - 11s 903ms/step - loss: 0.6938 - accuracy: 0.5431 - val_loss: 0.6709 - val_accuracy: 0.6187
# Epoch 3/30
# 12/12 [==============================] - ETA: 0s - loss: 0.6737 - accuracy: 0.5644
# Epoch 3: val_loss did not improve from 0.67088
# 12/12 [==============================] - 10s 846ms/step - loss: 0.6737 - accuracy: 0.5644 - val_loss: 0.7726 - val_accuracy: 0.4960
# Epoch 4/30
# 12/12 [==============================] - ETA: 0s - loss: 0.6620 - accuracy: 0.6018
# Epoch 4: val_loss improved from 0.67088 to 0.57784, saving model to ./history\bus.hdf5
# 12/12 [==============================] - 10s 833ms/step - loss: 0.6620 - accuracy: 0.6018 - val_loss: 0.5778 - val_accuracy: 0.7520
# Epoch 5/30
# 12/12 [==============================] - ETA: 0s - loss: 0.6094 - accuracy: 0.6747
# Epoch 5: val_loss improved from 0.57784 to 0.53730, saving model to ./history\bus.hdf5
# 12/12 [==============================] - 11s 895ms/step - loss: 0.6094 - accuracy: 0.6747 - val_loss: 0.5373 - val_accuracy: 0.7600
# Epoch 6/30
# 12/12 [==============================] - ETA: 0s - loss: 0.5587 - accuracy: 0.7147
# Epoch 6: val_loss improved from 0.53730 to 0.52918, saving model to ./history\bus.hdf5
# 12/12 [==============================] - 10s 841ms/step - loss: 0.5587 - accuracy: 0.7147 - val_loss: 0.5292 - val_accuracy: 0.7413
# Epoch 7/30
# 12/12 [==============================] - ETA: 0s - loss: 0.5265 - accuracy: 0.7680
# Epoch 7: val_loss improved from 0.52918 to 0.47460, saving model to ./history\bus.hdf5
# 12/12 [==============================] - 11s 902ms/step - loss: 0.5265 - accuracy: 0.7680 - val_loss: 0.4746 - val_accuracy: 0.7893
# Epoch 8/30
# 12/12 [==============================] - ETA: 0s - loss: 0.5183 - accuracy: 0.7698
# Epoch 8: val_loss did not improve from 0.47460
# 12/12 [==============================] - 10s 815ms/step - loss: 0.5183 - accuracy: 0.7698 - val_loss: 0.5117 - val_accuracy: 0.7840
# Epoch 9/30
# 12/12 [==============================] - ETA: 0s - loss: 0.4855 - accuracy: 0.8018
# Epoch 9: val_loss did not improve from 0.47460
# 12/12 [==============================] - 10s 818ms/step - loss: 0.4855 - accuracy: 0.8018 - val_loss: 0.4929 - val_accuracy: 0.7867
# Epoch 10/30
# 12/12 [==============================] - ETA: 0s - loss: 0.4306 - accuracy: 0.8169
# Epoch 10: val_loss did not improve from 0.47460
# 12/12 [==============================] - 10s 860ms/step - loss: 0.4306 - accuracy: 0.8169 - val_loss: 0.5516 - val_accuracy: 0.8000
# Epoch 11/30
# 12/12 [==============================] - ETA: 0s - loss: 0.4077 - accuracy: 0.8373
# Epoch 11: val_loss improved from 0.47460 to 0.40894, saving model to ./history\bus.hdf5
# 12/12 [==============================] - 10s 835ms/step - loss: 0.4077 - accuracy: 0.8373 - val_loss: 0.4089 - val_accuracy: 0.8213
# Epoch 12/30
# 12/12 [==============================] - ETA: 0s - loss: 0.3060 - accuracy: 0.8871
# Epoch 12: val_loss did not improve from 0.40894
# 12/12 [==============================] - 10s 863ms/step - loss: 0.3060 - accuracy: 0.8871 - val_loss: 0.4434 - val_accuracy: 0.8133
# Epoch 13/30
# 12/12 [==============================] - ETA: 0s - loss: 0.2906 - accuracy: 0.8862
# Epoch 13: val_loss did not improve from 0.40894
# 12/12 [==============================] - 10s 869ms/step - loss: 0.2906 - accuracy: 0.8862 - val_loss: 0.5195 - val_accuracy: 0.8187
# Epoch 14/30
# 12/12 [==============================] - ETA: 0s - loss: 0.2330 - accuracy: 0.9111
# Epoch 14: val_loss did not improve from 0.40894
# 12/12 [==============================] - 10s 825ms/step - loss: 0.2330 - accuracy: 0.9111 - val_loss: 0.5173 - val_accuracy: 0.8000
# Epoch 15/30
# 12/12 [==============================] - ETA: 0s - loss: 0.2189 - accuracy: 0.9182
# Epoch 15: val_loss did not improve from 0.40894
# 12/12 [==============================] - 11s 878ms/step - loss: 0.2189 - accuracy: 0.9182 - val_loss: 0.4861 - val_accuracy: 0.8240
# Epoch 16/30
# 12/12 [==============================] - ETA: 0s - loss: 0.1686 - accuracy: 0.9404
# Epoch 16: val_loss did not improve from 0.40894
# 12/12 [==============================] - 10s 839ms/step - loss: 0.1686 - accuracy: 0.9404 - val_loss: 0.5489 - val_accuracy: 0.8347

# %%
model.evaluate(X_train, y_train)
model.evaluate(X_test, y_test)
# Out:
# 47/47 [==============================] - 3s 59ms/step - loss: 0.2017 - accuracy: 0.9413
# 16/16 [==============================] - 1s 59ms/step - loss: 0.6121 - accuracy: 0.8320
# [0.61211758852005, 0.8320000171661377]

# %%
val_loss = history.history['val_loss']
loss = history.history['loss']

x_len = np.arange(len(loss))
plt.plot(x_len, val_loss, marker='.', c="red", label='val_loss')
plt.plot(x_len, loss, marker='.', c="blue", label='loss')

plt.legend(loc='upper right')
plt.grid()
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()

# %%
val_accuracy = history.history['val_accuracy']
accuracy = history.history['accuracy']

x_len = np.arange(len(accuracy))
plt.plot(x_len, val_accuracy, marker='.', c="red", label='val_accuracy')
plt.plot(x_len, accuracy, marker='.', c="blue", label='accuracy')

plt.legend(loc='upper right')
plt.grid()
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.show()

# %%
model.save(f"./models/{target.lower()}.hdf5")

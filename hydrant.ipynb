# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D
from keras.callbacks import ModelCheckpoint, EarlyStopping
import matplotlib.pyplot as plt
import numpy as np
import cv2
from sklearn.model_selection import train_test_split

# %% [markdown]
# # 데이터셋 생성

# %%
import os

X = np.empty((2000, 64, 64, 3))
Y = np.empty((2000,))

target = 'Hydrant'

folders = os.listdir('./images')
folders.remove(target)
folders.remove('Other')

files = os.listdir(f'./images/{target}')
for i in range(1000):
    x = cv2.imread(f"./images/{target}/{files[i]}")
    X[i] = cv2.resize(x, (64, 64))
    Y[i] = 1

files = os.listdir('./images/Other')
for i in range(300):
    x = cv2.imread(f"./images/Other/{files[i]}")
    X[i+1000] = cv2.resize(x, (64, 64))
    Y[i+1000] = 0

for f in range(7):
    files = os.listdir(f'./images/{folders[f]}')
    for i in range(100):
        x = cv2.imread(f"./images/{folders[f]}/{files[i]}")
        X[1300+f*100+i] = cv2.resize(x, (64, 64))
        Y[1300+f*100+i] = 0

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, random_state=0)

# %%
print(X_train.shape)
print(X_test.shape)
print( y_train.shape)
print(y_test.shape)
# Out:
# (1500, 64, 64, 3)
# (500, 64, 64, 3)
# (1500,)
# (500,)

# %% [markdown]
# # 모델 생성

# %%
model = Sequential()
model.add(Conv2D(16, (3,3), activation='relu', input_shape=(64, 64, 3)))
model.add(MaxPooling2D())
model.add(Conv2D(64, (3,3), activation='relu'))
model.add(MaxPooling2D())
model.add(Conv2D(256, (3,3), activation='relu'))
model.add(MaxPooling2D())
model.add(Conv2D(1024, (3,3), activation='relu'))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(
    optimizer='adam', 
    loss='binary_crossentropy', 
    metrics=[
        'accuracy',
    ],
)

# %%
modelpath=f"./history/{target.lower()}.hdf5"
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', verbose=1, save_best_only=True)
early_stopping_callback = EarlyStopping(monitor='val_loss', patience=5)

# %%
history = model.fit(X_train, y_train, validation_split=0.25, epochs=30, batch_size=100, verbose='auto', callbacks=[early_stopping_callback,checkpointer])
# Out:
# Epoch 1/30
# 12/12 [==============================] - ETA: 0s - loss: 1.7680 - accuracy: 0.4640
# Epoch 1: val_loss improved from inf to 0.70187, saving model to ./history\hydrant.hdf5
# 12/12 [==============================] - 10s 719ms/step - loss: 1.7680 - accuracy: 0.4640 - val_loss: 0.7019 - val_accuracy: 0.4747
# Epoch 2/30
# 12/12 [==============================] - ETA: 0s - loss: 0.6904 - accuracy: 0.5058
# Epoch 2: val_loss improved from 0.70187 to 0.66463, saving model to ./history\hydrant.hdf5
# 12/12 [==============================] - 9s 773ms/step - loss: 0.6904 - accuracy: 0.5058 - val_loss: 0.6646 - val_accuracy: 0.4747
# Epoch 3/30
# 12/12 [==============================] - ETA: 0s - loss: 0.6260 - accuracy: 0.6347
# Epoch 3: val_loss improved from 0.66463 to 0.55866, saving model to ./history\hydrant.hdf5
# 12/12 [==============================] - 10s 798ms/step - loss: 0.6260 - accuracy: 0.6347 - val_loss: 0.5587 - val_accuracy: 0.8480
# Epoch 4/30
# 12/12 [==============================] - ETA: 0s - loss: 0.4615 - accuracy: 0.8276
# Epoch 4: val_loss improved from 0.55866 to 0.53093, saving model to ./history\hydrant.hdf5
# 12/12 [==============================] - 10s 798ms/step - loss: 0.4615 - accuracy: 0.8276 - val_loss: 0.5309 - val_accuracy: 0.7467
# Epoch 5/30
# 12/12 [==============================] - ETA: 0s - loss: 0.3313 - accuracy: 0.8747
# Epoch 5: val_loss improved from 0.53093 to 0.34343, saving model to ./history\hydrant.hdf5
# 12/12 [==============================] - 10s 799ms/step - loss: 0.3313 - accuracy: 0.8747 - val_loss: 0.3434 - val_accuracy: 0.8853
# Epoch 6/30
# 12/12 [==============================] - ETA: 0s - loss: 0.2984 - accuracy: 0.8782
# Epoch 6: val_loss improved from 0.34343 to 0.25331, saving model to ./history\hydrant.hdf5
# 12/12 [==============================] - 10s 796ms/step - loss: 0.2984 - accuracy: 0.8782 - val_loss: 0.2533 - val_accuracy: 0.9173
# Epoch 7/30
# 12/12 [==============================] - ETA: 0s - loss: 0.2616 - accuracy: 0.9111
# Epoch 7: val_loss did not improve from 0.25331
# 12/12 [==============================] - 9s 777ms/step - loss: 0.2616 - accuracy: 0.9111 - val_loss: 0.2551 - val_accuracy: 0.9067
# Epoch 8/30
# 12/12 [==============================] - ETA: 0s - loss: 0.2102 - accuracy: 0.9218
# Epoch 8: val_loss improved from 0.25331 to 0.22857, saving model to ./history\hydrant.hdf5
# 12/12 [==============================] - 10s 798ms/step - loss: 0.2102 - accuracy: 0.9218 - val_loss: 0.2286 - val_accuracy: 0.9307
# Epoch 9/30
# 12/12 [==============================] - ETA: 0s - loss: 0.2776 - accuracy: 0.9067
# Epoch 9: val_loss did not improve from 0.22857
# 12/12 [==============================] - 9s 784ms/step - loss: 0.2776 - accuracy: 0.9067 - val_loss: 0.2601 - val_accuracy: 0.9120
# Epoch 10/30
# 12/12 [==============================] - ETA: 0s - loss: 0.2284 - accuracy: 0.9182
# Epoch 10: val_loss did not improve from 0.22857
# 12/12 [==============================] - 9s 761ms/step - loss: 0.2284 - accuracy: 0.9182 - val_loss: 0.4550 - val_accuracy: 0.9120
# Epoch 11/30
# 12/12 [==============================] - ETA: 0s - loss: 0.1840 - accuracy: 0.9422
# Epoch 11: val_loss improved from 0.22857 to 0.20036, saving model to ./history\hydrant.hdf5
# 12/12 [==============================] - 9s 793ms/step - loss: 0.1840 - accuracy: 0.9422 - val_loss: 0.2004 - val_accuracy: 0.9333
# Epoch 12/30
# 12/12 [==============================] - ETA: 0s - loss: 0.1127 - accuracy: 0.9582
# Epoch 12: val_loss did not improve from 0.20036
# 12/12 [==============================] - 9s 766ms/step - loss: 0.1127 - accuracy: 0.9582 - val_loss: 0.2092 - val_accuracy: 0.9147
# Epoch 13/30
# 12/12 [==============================] - ETA: 0s - loss: 0.1172 - accuracy: 0.9627
# Epoch 13: val_loss did not improve from 0.20036
# 12/12 [==============================] - 9s 776ms/step - loss: 0.1172 - accuracy: 0.9627 - val_loss: 0.2445 - val_accuracy: 0.9227
# Epoch 14/30
# 12/12 [==============================] - ETA: 0s - loss: 0.1654 - accuracy: 0.9227
# Epoch 14: val_loss did not improve from 0.20036
# 12/12 [==============================] - 9s 766ms/step - loss: 0.1654 - accuracy: 0.9227 - val_loss: 0.2135 - val_accuracy: 0.9333
# Epoch 15/30
# 12/12 [==============================] - ETA: 0s - loss: 0.1192 - accuracy: 0.9609
# Epoch 15: val_loss did not improve from 0.20036
# 12/12 [==============================] - 9s 766ms/step - loss: 0.1192 - accuracy: 0.9609 - val_loss: 0.2131 - val_accuracy: 0.9440
# Epoch 16/30
# 12/12 [==============================] - ETA: 0s - loss: 0.1198 - accuracy: 0.9564
# Epoch 16: val_loss improved from 0.20036 to 0.19677, saving model to ./history\hydrant.hdf5
# 12/12 [==============================] - 9s 773ms/step - loss: 0.1198 - accuracy: 0.9564 - val_loss: 0.1968 - val_accuracy: 0.9333
# Epoch 17/30
# 12/12 [==============================] - ETA: 0s - loss: 0.2032 - accuracy: 0.9262
# Epoch 17: val_loss did not improve from 0.19677
# 12/12 [==============================] - 9s 777ms/step - loss: 0.2032 - accuracy: 0.9262 - val_loss: 0.2270 - val_accuracy: 0.9333
# Epoch 18/30
# 12/12 [==============================] - ETA: 0s - loss: 0.1042 - accuracy: 0.9547
# Epoch 18: val_loss did not improve from 0.19677
# 12/12 [==============================] - 9s 773ms/step - loss: 0.1042 - accuracy: 0.9547 - val_loss: 0.3545 - val_accuracy: 0.9120
# Epoch 19/30
# 12/12 [==============================] - ETA: 0s - loss: 0.1253 - accuracy: 0.9529
# Epoch 19: val_loss improved from 0.19677 to 0.18992, saving model to ./history\hydrant.hdf5
# 12/12 [==============================] - 9s 785ms/step - loss: 0.1253 - accuracy: 0.9529 - val_loss: 0.1899 - val_accuracy: 0.9467
# Epoch 20/30
# 12/12 [==============================] - ETA: 0s - loss: 0.0364 - accuracy: 0.9893
# Epoch 20: val_loss did not improve from 0.18992
# 12/12 [==============================] - 9s 769ms/step - loss: 0.0364 - accuracy: 0.9893 - val_loss: 0.2647 - val_accuracy: 0.9440
# Epoch 21/30
# 12/12 [==============================] - ETA: 0s - loss: 0.0371 - accuracy: 0.9858
# Epoch 21: val_loss did not improve from 0.18992
# 12/12 [==============================] - 9s 763ms/step - loss: 0.0371 - accuracy: 0.9858 - val_loss: 0.2366 - val_accuracy: 0.9227
# Epoch 22/30
# 12/12 [==============================] - ETA: 0s - loss: 0.0243 - accuracy: 0.9938
# Epoch 22: val_loss did not improve from 0.18992
# 12/12 [==============================] - 9s 762ms/step - loss: 0.0243 - accuracy: 0.9938 - val_loss: 0.2766 - val_accuracy: 0.9280
# Epoch 23/30
# 12/12 [==============================] - ETA: 0s - loss: 0.0208 - accuracy: 0.9947
# Epoch 23: val_loss did not improve from 0.18992
# 12/12 [==============================] - 9s 771ms/step - loss: 0.0208 - accuracy: 0.9947 - val_loss: 0.2817 - val_accuracy: 0.9547
# Epoch 24/30
# 12/12 [==============================] - ETA: 0s - loss: 0.0077 - accuracy: 0.9982
# Epoch 24: val_loss did not improve from 0.18992
# 12/12 [==============================] - 9s 776ms/step - loss: 0.0077 - accuracy: 0.9982 - val_loss: 0.3542 - val_accuracy: 0.9547

# %%
model.evaluate(X_train, y_train)
model.evaluate(X_test, y_test)
# Out:
# 47/47 [==============================] - 2s 46ms/step - loss: 0.0918 - accuracy: 0.9880
# 16/16 [==============================] - 1s 49ms/step - loss: 0.4320 - accuracy: 0.9500
# [0.4319511651992798, 0.949999988079071]

# %%
val_loss = history.history['val_loss']
loss = history.history['loss']

x_len = np.arange(len(loss))
plt.plot(x_len, val_loss, marker='.', c="red", label='val_loss')
plt.plot(x_len, loss, marker='.', c="blue", label='loss')

plt.legend(loc='upper right')
plt.grid()
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()

# %%
val_accuracy = history.history['val_accuracy']
accuracy = history.history['accuracy']

x_len = np.arange(len(accuracy))
plt.plot(x_len, val_accuracy, marker='.', c="red", label='val_accuracy')
plt.plot(x_len, accuracy, marker='.', c="blue", label='accuracy')

plt.legend(loc='upper right')
plt.grid()
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.show()

# %%
model.save(f"./models/{target.lower()}.hdf5")
